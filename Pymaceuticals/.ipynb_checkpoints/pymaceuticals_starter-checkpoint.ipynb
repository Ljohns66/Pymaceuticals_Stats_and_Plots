# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# - With this data it seems that Capomulin and Ramicane seem to have lower tumor volumes and therefore better results. We can also see that mouse weight seems to play a part in the size of the tumor as well.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import linregress

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single DataFrame
full_mouse_data = study_results.merge(mouse_metadata, how="inner", on="Mouse ID")

# Display the data table for preview
full_mouse_data
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        b128          5           45.651331                 0    Capomulin
# 2        b128         10           43.270852                 0    Capomulin
# 3        b128         15           43.784893                 0    Capomulin
# 4        b128         20           42.731552                 0    Capomulin
# ...       ...        ...                 ...               ...          ...
# 1888     m601         25           33.118756                 1    Capomulin
# 1889     m601         30           31.758275                 1    Capomulin
# 1890     m601         35           30.834357                 1    Capomulin
# 1891     m601         40           31.378045                 1    Capomulin
# 1892     m601         45           28.430964                 1    Capomulin
#
#          Sex  Age_months  Weight (g)
# ...

# %%
# Get column names - check them
print(mouse_metadata.columns.tolist())
print(study_results.columns.tolist())
# Out:
# ['Mouse ID', 'Drug Regimen', 'Sex', 'Age_months', 'Weight (g)']
# ['Mouse ID', 'Timepoint', 'Tumor Volume (mm3)', 'Metastatic Sites']

# %%
# Checking the number of mice.
print(len(full_mouse_data["Mouse ID"].unique()))
# Out:
# 249

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint
# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicate_ids = full_mouse_data.loc[full_mouse_data.duplicated(subset=['Mouse ID', 'Timepoint'], keep='first'),'Mouse ID'].unique()
duplicate_ids
# Out:
# array(['g989'], dtype=object)

# %%
# Optional: Get all the data for the duplicate mouse ID. 
full_mouse_data[full_mouse_data['Mouse ID'].isin(duplicate_ids)==True]
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 860     g989          0           45.000000                 0     Propriva
# 861     g989          0           45.000000                 0     Propriva
# 862     g989          5           48.786801                 0     Propriva
# 863     g989          5           47.570392                 0     Propriva
# 864     g989         10           51.745156                 0     Propriva
# 865     g989         10           49.880528                 0     Propriva
# 866     g989         15           51.325852                 1     Propriva
# 867     g989         15           53.442020                 0     Propriva
# 868     g989         20           55.326122                 1     Propriva
# 869     g989         20           54.657650                 1     Propriva
# 870     g989         25           56.045564                 1     Propriva
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
mouse_data_clean = full_mouse_data[full_mouse_data['Mouse ID'].isin(duplicate_ids)==False]
mouse_data_clean
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        b128          5           45.651331                 0    Capomulin
# 2        b128         10           43.270852                 0    Capomulin
# 3        b128         15           43.784893                 0    Capomulin
# 4        b128         20           42.731552                 0    Capomulin
# ...       ...        ...                 ...               ...          ...
# 1888     m601         25           33.118756                 1    Capomulin
# 1889     m601         30           31.758275                 1    Capomulin
# 1890     m601         35           30.834357                 1    Capomulin
# 1891     m601         40           31.378045                 1    Capomulin
# 1892     m601         45           28.430964                 1    Capomulin
#
#          Sex  Age_months  Weight (g)
# ...

# %%
# Checking the number of mice in the clean DataFrame.
print(len(mouse_data_clean["Mouse ID"].unique()))
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary DataFrame.
drug_data = mouse_data_clean.groupby("Drug Regimen")
mean_tumor = drug_data["Tumor Volume (mm3)"].mean()
median_tumor = drug_data["Tumor Volume (mm3)"].median()
var_tumor = drug_data["Tumor Volume (mm3)"].var()
std_dev_tumor = drug_data["Tumor Volume (mm3)"].std()
sem_tumor = drug_data["Tumor Volume (mm3)"].sem()

drug_summary = pd.DataFrame({"Mean Tumor Volume": mean_tumor, "Median Tumor Volume": median_tumor,
                            "Tumor Volume Variance": var_tumor, "Tumor Volume Standard Deviation": std_dev_tumor,
                            "Tumor Volume Standard Error of the Mean": sem_tumor})

# %%
drug_summary
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.320930            50.446266              43.852013
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Standard Deviation  \
# Drug Regimen
# Capomulin                            4.994774
# ...

# %%
# A more advanced method to generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM of the tumor volume for each regimen (only one method is required in the solution)

# Using the aggregation method, produce the same summary statistics in a single line
agg_drug_summary = drug_data.aggregate({"Tumor Volume (mm3)": ['mean', 'median', 'var', 'std', 'sem']})
agg_drug_summary

# Wow, cool! Would just need to rename.
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Gather counts per drug and sort
timepoints_per_drug = drug_data["Timepoint"].count()
timepoints_per_drug = timepoints_per_drug.sort_values(ascending=False)
drugs = ["Capomulin", "Ramicane", "Ketapril", "Naftisol", "Zoniferol", "Placebo", "Stelasyn", "Ceftamin", "Infubinol", "Propriva"]
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.

plt.bar(drugs, timepoints_per_drug, color="b", align="center")
plt.xticks([value for value in drugs], drugs, rotation="vertical")
plt.title("Timepoint Per Drug Regimen")
plt.xlabel("Drug Regimen")
plt.ylabel("# of Observed Mouse Timepoints")
# Out:
# Text(0, 0.5, '# of Observed Mouse Timepoints')

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using pyplot.
drug_bar_graph = timepoints_per_drug.plot(kind="bar", facecolor="blue", figsize=(6,4),
                                  title="Timepoint Per Drug Regimen",
                                   xlabel="Drug Regimen",
                                  ylabel="# of Observed Mouse Timepoints",
                                  legend=False)

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
mouse_f = mouse_data_clean.loc[mouse_data_clean["Sex"]=="Female", "Mouse ID"].count()
mouse_m = mouse_data_clean.loc[mouse_data_clean["Sex"]=="Male", "Mouse ID"].count()
sex_count = [mouse_f, mouse_m]
sex = ["Female", "Male"]
colors = ["pink", "lightskyblue"]

plt.pie(sex_count, labels=sex, colors=colors, autopct="%1.0f%%", startangle=90)
plt.axis=()
plt.title("Sex")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
sex_data = mouse_data_clean.groupby("Sex")
mouse_sex = sex_data["Sex"].count()

drug_bar_graph = mouse_sex.plot(kind="pie", colors=colors, autopct="%1.0f%%",
                                startangle=90, title="Sex", label="")

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
max_timepoints = mouse_data_clean.groupby(['Mouse ID']).max()
max_timepoints

# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
max_df = pd.merge(max_timepoints, mouse_data_clean, on=["Timepoint", "Mouse ID", "Drug Regimen"])
max_df.reset_index()

max_df
# Out:
#      Timepoint Mouse ID  Tumor Volume (mm3)_x  Metastatic Sites_x  \
# 0           45     a203             67.973419                   2
# 1           45     a251             65.525743                   1
# 2           45     a262             70.717621                   4
# 3           45     a275             62.999356                   3
# 4           30     a366             63.440686                   1
# ..         ...      ...                   ...                 ...
# 243         10     z435             48.710661                   0
# 244         45     z578             45.000000                   0
# 245         45     z581             62.754451                   3
# 246         45     z795             65.741070                   3
# 247         45     z969             73.867845                   4
#
#     Drug Regimen   Sex_x  Age_months_x  Weight (g)_x  Tumor Volume (mm3)_y  \
# 0      Infubinol  Female            20            23             67.973419
# ...

# %%
max_cap = max_df.loc[max_df["Drug Regimen"] == "Capomulin"]
max_cap["Tumor Volume (mm3)_y"]
# Out:
# 19     38.982878
# 24     38.939633
# 61     30.485985
# 64     37.074024
# 66     40.159220
# 80     47.685963
# 83     37.311846
# 85     38.125164
# 87     38.753265
# 108    41.483008
# 115    38.846876
# 121    28.430964
# 124    33.329098
# 162    46.539206
# 163    32.377357
# 169    41.581521
# 174    23.343598
# 180    40.728578
# 183    34.455298
# 192    31.023923
# 204    40.658124
# 208    39.952347
# 220    36.041047
# 226    28.484033
# 239    31.896238
# Name: Tumor Volume (mm3)_y, dtype: float64

# %%
# Put treatments into a list to sort (later for plot labels)
treatments = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]

# Create empty list to fill with tumor vol data (for plotting)
tumor_vol_data = []

# Calculate the IQR and quantitatively determine if there are any potential outliers. 

# Locate the rows which contain mice on each drug and get the tumor volumes

for drugs in treatments:
    max_drug = max_df.loc[max_df["Drug Regimen"] == drugs]
    tumor_vol_data.append(max_drug["Tumor Volume (mm3)_y"])  

    # add subset
    
    quartiles = max_drug["Tumor Volume (mm3)_y"].quantile([0.25,.5,.75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    IQR = upperq-lowerq
    
    # Determine outliers using upper and lower bounds
    
    lowerbound = lowerq-(1.5*IQR)
    upperbound = upperq+(1.5*IQR)
    outliers = max_drug.loc[(max_drug["Tumor Volume (mm3)_y"] > upperbound) | (max_drug["Tumor Volume (mm3)_y"] < lowerbound)]
    
    print(f"{drugs}'s potential outliers: {outliers['Tumor Volume (mm3)_y']}")
# Out:
# Capomulin's potential outliers: Series([], Name: Tumor Volume (mm3)_y, dtype: float64)
# Ramicane's potential outliers: Series([], Name: Tumor Volume (mm3)_y, dtype: float64)
# Infubinol's potential outliers: 31    36.321346
# Name: Tumor Volume (mm3)_y, dtype: float64
# Ceftamin's potential outliers: Series([], Name: Tumor Volume (mm3)_y, dtype: float64)

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.
fig1, ax1 = plt.subplots()
ax1.set_ylabel('Final Tumor Volume (mm3)')
ax1.boxplot(tumor_vol_data)
ax1.set_xticklabels(treatments)
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin
single_mouse = mouse_data_clean.loc[mouse_data_clean["Mouse ID"] == "b128"]
single_mouse
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0           45.000000                 0    Capomulin
# 1     b128          5           45.651331                 0    Capomulin
# 2     b128         10           43.270852                 0    Capomulin
# 3     b128         15           43.784893                 0    Capomulin
# 4     b128         20           42.731552                 0    Capomulin
# 5     b128         25           43.262145                 1    Capomulin
# 6     b128         30           40.605335                 1    Capomulin
# 7     b128         35           37.967644                 1    Capomulin
# 8     b128         40           38.379726                 2    Capomulin
# 9     b128         45           38.982878                 2    Capomulin
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1  Female           9          22
# 2  Female           9          22
# ...

# %%
# Collect timepoint and volume data for graph
timepoints_single_mouse = single_mouse["Timepoint"]
tumor_vol_single_mouse = single_mouse["Tumor Volume (mm3)"]

#Plot data and add labels to graph
plt.plot(timepoints_single_mouse, tumor_vol_single_mouse)
plt.xlabel("Timepoint (days)")
plt.ylabel("Tumor Volume (mm3)")
plt.title("Capomulin Treatment on mouse B128")
plt.show()

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen
capomulin_treatments = mouse_data_clean.loc[mouse_data_clean["Drug Regimen"] == "Capomulin"]
capomulin_average = capomulin_treatments.groupby(['Mouse ID']).mean()
capomulin_average
# Out:
# C:\Users\12182\AppData\Local\Temp\ipykernel_14248\1551511410.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   capomulin_average = capomulin_treatments.groupby(['Mouse ID']).mean()
#           Timepoint  Tumor Volume (mm3)  Metastatic Sites  Age_months  \
# Mouse ID
# b128           22.5           41.963636              0.70         9.0
# b742           22.5           40.083699              0.00         7.0
# f966           10.0           36.505973              0.00        16.0
# g288           22.5           41.990097              0.80         3.0
# g316           22.5           44.613344              1.00        22.0
# i557           22.5           44.805810              0.20         1.0
# i738           22.5           39.141053              0.60        23.0
# ...

# %%
# Collect data to graph
y_values = capomulin_average['Tumor Volume (mm3)']
x_values = capomulin_average['Weight (g)']

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen
plt.scatter(x_values, y_values)
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")
plt.title("Mouse Weight vs Average Tumor Volume")
plt.tight_layout
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and a linear regression model 
# for mouse weight and average observed tumor volume for the entire Capomulin regimen
plt.scatter(x_values, y_values)
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")
plt.title("Mouse Weight vs Average Tumor Volume")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

plt.tight_layout
plt.show

print(f"The correlation between mouse weight and the average tumor volume is {round(st.pearsonr(x_values, y_values)[0],2)}")
# Out:
# The correlation between mouse weight and the average tumor volume is 0.84
